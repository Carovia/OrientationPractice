# %%
import os
import time
import copy
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
from nets.yolo4 import YoloBody
from nets.yolo_training import YOLOLoss, Generator

# %%
#---------------------------------------------------#
#   获得类和先验框
#---------------------------------------------------#
def get_classes(classes_path):
    '''loads the classes'''
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names


def get_anchors(anchors_path):
    '''loads the anchors from a file'''
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    return np.array(anchors).reshape([-1,3,2])[::-1,:,:]


#---------------------------------------------------#
#   训练一个epoch
#---------------------------------------------------#
def fit_one_epoch(net, yolo_losses, epoch, epoch_size, epoch_size_val, gen,genval, Epoch, cuda, optimizer, lr_scheduler):
    total_loss = 0
    val_loss = 0
    print('\n' + '-' * 10 + 'Train one epoch.' + '-' * 10)
    print('Epoch:'+ str(epoch+1) + '/' + str(Epoch))
    print('Start Training.')
    net.train()
    for iteration in range(epoch_size):
        start_time = time.time()
        images, targets = next(gen)
        with torch.no_grad():
            if cuda:
                images = Variable(torch.from_numpy(images).type(torch.FloatTensor)).cuda()
                targets = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets]
            else:
                images = Variable(torch.from_numpy(images).type(torch.FloatTensor))
                targets = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets]
        optimizer.zero_grad()
        outputs = net(images)
        losses = []
        for i in range(3):
            loss_item = yolo_losses[i](outputs[i], targets)
            losses.append(loss_item[0])
        loss = sum(losses)
        loss.backward()
        optimizer.step()
        lr_scheduler.step()

        total_loss += loss
        waste_time = time.time() - start_time
        if iteration == 0 or (iteration+1) % 10 == 0:
            print('step:' + str(iteration+1) + '/' + str(epoch_size) + ' || Total Loss: %.4f || %.4fs/step' % (total_loss/(iteration+1), waste_time))
    print('Finish Training.')
    '''        
    print('Start Validation.')
    net.eval()
    for iteration in range(epoch_size_val):
        images_val, targets_val = next(genval)

        with torch.no_grad():
            if cuda:
                images_val = Variable(torch.from_numpy(images_val).type(torch.FloatTensor)).cuda()
                targets_val = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets_val]
            else:
                images_val = Variable(torch.from_numpy(images_val).type(torch.FloatTensor))
                targets_val = [Variable(torch.from_numpy(ann).type(torch.FloatTensor)) for ann in targets_val]
            optimizer.zero_grad()
            outputs = net(images_val)
            losses = []
            for i in range(3):
                loss_item = yolo_losses[i](outputs[i], targets_val)
                losses.append(loss_item[0])
            loss = sum(losses)
            val_loss += loss
    print('Finish Validation')
    '''
    print('Total Loss: %.4f || Val Loss: %.4f ' % (total_loss/(epoch_size+1), val_loss/(epoch_size_val+1)))
    
    return total_loss/(epoch_size+1), val_loss/(epoch_size_val+1)

# %%
#-------------------------------#
#   输入的shape大小
#   显存比较小可以使用416x416
#   显存比较大可以使用608x608
#-------------------------------#
#input_shape = (416,416)
input_shape = (608, 608)

#-------------------------------#
#   tricks的使用设置
#-------------------------------#
Cosine_lr = True
mosaic = True
# 用于设定是否使用cuda
Cuda = True
smoooth_label = 0.03

#-------------------------------#
#   获得训练集和验证集的annotations
#   
#-------------------------------#
train_annotation_path = 'model_data/train.txt'
val_annotation_path = 'model_data/val.txt'

#-------------------------------#
#   获得先验框和类
#-------------------------------#
anchors_path = 'model_data/yolo_anchors.txt'
classes_path = 'model_data/mask_classes.txt'   
class_names = get_classes(classes_path)
anchors = get_anchors(anchors_path)
num_classes = len(class_names)

# %%
# 创建模型
model = YoloBody(len(anchors[0]), num_classes)
model_path = "model_data/yolov4_maskdetect_weights0.pth"
# model_path = "model_data/yolov4_maskdetect_weights0.pth"
# 加快模型训练的效率
print('Loading pretrained model weights.')
model_dict = model.state_dict()
pretrained_dict = torch.load(model_path)
pretrained_dict = {k: v for k, v in pretrained_dict.items() if np.shape(model_dict[k]) ==  np.shape(v)}
model_dict.update(pretrained_dict)
model.load_state_dict(model_dict)
print('Finished!')

if Cuda:
    net = torch.nn.DataParallel(model)
    cudnn.benchmark = True
    net = net.cuda()

# 建立loss函数
yolo_losses = []
for i in range(3):
    yolo_losses.append(YOLOLoss(np.reshape(anchors, [-1,2]), num_classes, \
                                (input_shape[1], input_shape[0]), smoooth_label, Cuda))
# read train lines and val lines
with open(train_annotation_path) as f:
    train_lines = f.readlines()
with open(val_annotation_path) as f:
    val_lines = f.readlines()
num_train = len(train_lines)
num_val = len(val_lines)
# Out:
# Loading pretrained model weights.
# Finished!

# %%
#------------------------------------#
#   先冻结backbone训练
#------------------------------------#
lr = 1e-3
Batch_size = 4
Init_Epoch = 0
Freeze_Epoch = 25
        
optimizer = optim.Adam(net.parameters(), lr, weight_decay=5e-4)
if Cosine_lr:
    lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5, eta_min=1e-5)
else:
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

gen = Generator(Batch_size, train_lines, (input_shape[0], input_shape[1])).generate(mosaic = mosaic)
gen_val = Generator(Batch_size, val_lines, (input_shape[0], input_shape[1])).generate(mosaic = False)
                        
epoch_size = int(max(1, num_train//Batch_size//2.5)) if mosaic else max(1, num_train//Batch_size)
epoch_size_val = num_val//Batch_size
for param in model.backbone.parameters():
    param.requires_grad = False

best_loss = 99999999.0
best_model_weights = copy.deepcopy(net.state_dict())
for epoch in range(Init_Epoch, Freeze_Epoch):
    total_loss, val_loss = fit_one_epoch(net, yolo_losses, epoch, epoch_size, epoch_size_val, gen, gen_val, 
                                         Freeze_Epoch, Cuda, optimizer, lr_scheduler)
    if total_loss < best_loss:
        best_loss = total_loss
        best_model_weights = copy.deepcopy(model.state_dict())
    with open('total_loss.csv', mode='a+') as total_loss_file:
        total_loss_file.write(str(total_loss.item()) + '\n')
    #with open('val_loss.csv', mode='a+') as val_loss_file:
    #    val_loss_file.write(str(val_loss.item()) + '\n')
torch.save(best_model_weights, 'model_data/yolov4_maskdetect_weights0.pth')
# Out:
# ----------Train one epoch.----------
# Epoch:1/25
# Start Training.
# /home/mist/MaskDetect-YOLOv4-PyTorch/nets/yolo_training.py:504: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   tmp_targets = np.array(targets)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /home/mist/pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# step:1/80 || Total Loss: 15015.4355 || 6.3311s/step
# step:10/80 || Total Loss: 11414.8857 || 1.5895s/step
# step:20/80 || Total Loss: 8910.9219 || 1.4485s/step
# step:30/80 || Total Loss: 7188.3159 || 1.2213s/step
# step:40/80 || Total Loss: 5974.7778 || 2.8243s/step
# step:50/80 || Total Loss: 5096.2876 || 1.5680s/step
# step:60/80 || Total Loss: 4436.5747 || 1.4322s/step
# step:70/80 || Total Loss: 3930.0063 || 1.5138s/step
# step:80/80 || Total Loss: 3527.0259 || 1.3748s/step
# Finish Training.
# Total Loss: 3483.4822 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:2/25
# Start Training.
# step:1/80 || Total Loss: 648.2054 || 1.1680s/step
# step:10/80 || Total Loss: 589.9666 || 1.5796s/step
# step:20/80 || Total Loss: 559.1953 || 1.5327s/step
# step:30/80 || Total Loss: 521.5851 || 1.4069s/step
# step:40/80 || Total Loss: 494.2169 || 1.3941s/step
# step:50/80 || Total Loss: 463.7503 || 1.4807s/step
# step:60/80 || Total Loss: 437.4377 || 1.3825s/step
# step:70/80 || Total Loss: 413.6038 || 1.8304s/step
# step:80/80 || Total Loss: 394.2931 || 1.4346s/step
# Finish Training.
# Total Loss: 389.4253 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:3/25
# Start Training.
# step:1/80 || Total Loss: 247.0912 || 1.4567s/step
# step:10/80 || Total Loss: 262.6350 || 1.4421s/step
# step:20/80 || Total Loss: 235.9945 || 1.5793s/step
# step:30/80 || Total Loss: 226.6599 || 1.6306s/step
# step:40/80 || Total Loss: 213.8563 || 1.1762s/step
# step:50/80 || Total Loss: 208.8987 || 1.5224s/step
# step:60/80 || Total Loss: 203.9464 || 1.4001s/step
# step:70/80 || Total Loss: 196.6240 || 1.3129s/step
# step:80/80 || Total Loss: 190.8176 || 1.3188s/step
# Finish Training.
# Total Loss: 188.4618 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:4/25
# Start Training.
# step:1/80 || Total Loss: 171.1455 || 1.6277s/step
# step:10/80 || Total Loss: 137.7798 || 1.5644s/step
# step:20/80 || Total Loss: 149.2371 || 2.0269s/step
# step:30/80 || Total Loss: 143.7918 || 1.4702s/step
# step:40/80 || Total Loss: 140.4641 || 1.4394s/step
# step:50/80 || Total Loss: 139.2717 || 1.6593s/step
# step:60/80 || Total Loss: 136.7181 || 1.5200s/step
# step:70/80 || Total Loss: 134.7544 || 1.7437s/step
# step:80/80 || Total Loss: 130.8804 || 1.4284s/step
# Finish Training.
# Total Loss: 129.2646 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:5/25
# Start Training.
# step:1/80 || Total Loss: 102.9866 || 1.5695s/step
# step:10/80 || Total Loss: 105.1412 || 1.5305s/step
# step:20/80 || Total Loss: 99.3341 || 1.2668s/step
# step:30/80 || Total Loss: 103.1401 || 1.3692s/step
# step:40/80 || Total Loss: 104.2918 || 1.5179s/step
# step:50/80 || Total Loss: 105.6070 || 1.5207s/step
# step:60/80 || Total Loss: 104.0943 || 1.4451s/step
# step:70/80 || Total Loss: 105.2122 || 2.3441s/step
# step:80/80 || Total Loss: 102.3274 || 1.5879s/step
# Finish Training.
# Total Loss: 101.0641 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:6/25
# Start Training.
# step:1/80 || Total Loss: 62.7723 || 1.3794s/step
# step:10/80 || Total Loss: 81.5378 || 1.9364s/step
# step:20/80 || Total Loss: 77.8213 || 1.4301s/step
# step:30/80 || Total Loss: 77.7502 || 1.5876s/step
# step:40/80 || Total Loss: 77.5513 || 1.5973s/step
# step:50/80 || Total Loss: 73.5499 || 1.4808s/step
# step:60/80 || Total Loss: 72.3897 || 1.4420s/step
# step:70/80 || Total Loss: 73.0943 || 1.4586s/step
# step:80/80 || Total Loss: 72.5404 || 1.4624s/step
# Finish Training.
# Total Loss: 71.6448 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:7/25
# Start Training.
# step:1/80 || Total Loss: 58.1368 || 1.6006s/step
# step:10/80 || Total Loss: 74.8641 || 1.5084s/step
# step:20/80 || Total Loss: 73.6262 || 1.6199s/step
# step:30/80 || Total Loss: 81.3296 || 1.8641s/step
# step:40/80 || Total Loss: 80.7031 || 2.0295s/step
# step:50/80 || Total Loss: 79.9827 || 1.3133s/step
# step:60/80 || Total Loss: 77.6357 || 1.5650s/step
# step:70/80 || Total Loss: 75.9449 || 1.2481s/step
# step:80/80 || Total Loss: 72.5514 || 1.5711s/step
# Finish Training.
# Total Loss: 71.6557 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:8/25
# Start Training.
# step:1/80 || Total Loss: 46.6739 || 1.5353s/step
# step:10/80 || Total Loss: 61.5551 || 1.5748s/step
# step:20/80 || Total Loss: 70.3158 || 1.2665s/step
# step:30/80 || Total Loss: 67.3521 || 1.3913s/step
# step:40/80 || Total Loss: 62.7147 || 1.2834s/step
# step:50/80 || Total Loss: 59.9760 || 1.4515s/step
# step:60/80 || Total Loss: 58.6582 || 1.3501s/step
# step:70/80 || Total Loss: 58.7848 || 1.6057s/step
# step:80/80 || Total Loss: 57.7749 || 2.2748s/step
# Finish Training.
# Total Loss: 57.0616 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:9/25
# Start Training.
# step:1/80 || Total Loss: 58.8861 || 1.4765s/step
# step:10/80 || Total Loss: 49.2757 || 1.3407s/step
# step:20/80 || Total Loss: 53.0970 || 1.2555s/step
# step:30/80 || Total Loss: 51.9811 || 1.4225s/step
# step:40/80 || Total Loss: 51.2028 || 1.5390s/step
# step:50/80 || Total Loss: 53.8142 || 1.5001s/step
# step:60/80 || Total Loss: 53.4170 || 1.6476s/step
# step:70/80 || Total Loss: 52.9300 || 1.3893s/step
# step:80/80 || Total Loss: 51.7146 || 1.5643s/step
# Finish Training.
# Total Loss: 51.0761 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:10/25
# Start Training.
# step:1/80 || Total Loss: 40.4253 || 1.2062s/step
# step:10/80 || Total Loss: 40.3039 || 1.4036s/step
# step:20/80 || Total Loss: 46.2325 || 1.7694s/step
# step:30/80 || Total Loss: 48.4048 || 3.7381s/step
# step:40/80 || Total Loss: 48.2970 || 1.5351s/step
# step:50/80 || Total Loss: 48.8052 || 1.4242s/step
# step:60/80 || Total Loss: 52.1164 || 1.3843s/step
# step:70/80 || Total Loss: 52.5791 || 1.5441s/step
# step:80/80 || Total Loss: 52.5312 || 1.9299s/step
# Finish Training.
# Total Loss: 51.8827 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:11/25
# Start Training.
# step:1/80 || Total Loss: 43.8122 || 1.9772s/step
# step:10/80 || Total Loss: 43.0547 || 1.4679s/step
# step:20/80 || Total Loss: 49.0874 || 1.3755s/step
# step:30/80 || Total Loss: 42.9256 || 1.2058s/step
# step:40/80 || Total Loss: 42.0801 || 1.4072s/step
# step:50/80 || Total Loss: 40.6778 || 1.6679s/step
# step:60/80 || Total Loss: 41.2223 || 1.5884s/step
# step:70/80 || Total Loss: 42.3999 || 1.4904s/step
# step:80/80 || Total Loss: 41.2975 || 1.2994s/step
# Finish Training.
# Total Loss: 40.7877 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:12/25
# Start Training.
# step:1/80 || Total Loss: 45.0569 || 1.4362s/step
# step:10/80 || Total Loss: 46.9337 || 1.6025s/step
# step:20/80 || Total Loss: 36.8276 || 1.2426s/step
# step:30/80 || Total Loss: 36.0690 || 1.7646s/step
# step:40/80 || Total Loss: 37.0494 || 1.9109s/step
# step:50/80 || Total Loss: 36.3599 || 1.2300s/step
# step:60/80 || Total Loss: 38.7040 || 1.8910s/step
# step:70/80 || Total Loss: 39.9674 || 1.3576s/step
# step:80/80 || Total Loss: 40.6579 || 1.4314s/step
# Finish Training.
# Total Loss: 40.1560 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:13/25
# Start Training.
# step:1/80 || Total Loss: 32.7415 || 1.5816s/step
# step:10/80 || Total Loss: 48.4830 || 1.2542s/step
# step:20/80 || Total Loss: 43.7126 || 1.1997s/step
# step:30/80 || Total Loss: 45.0689 || 1.6241s/step
# step:40/80 || Total Loss: 43.9477 || 1.1025s/step
# step:50/80 || Total Loss: 41.9793 || 2.3379s/step
# step:60/80 || Total Loss: 41.0997 || 1.4299s/step
# step:70/80 || Total Loss: 39.7771 || 1.3767s/step
# step:80/80 || Total Loss: 39.9483 || 1.3394s/step
# Finish Training.
# Total Loss: 39.4551 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:14/25
# Start Training.
# step:1/80 || Total Loss: 26.4163 || 1.5841s/step
# step:10/80 || Total Loss: 24.5976 || 1.5016s/step
# step:20/80 || Total Loss: 26.6195 || 1.4153s/step
# step:30/80 || Total Loss: 33.6862 || 1.5460s/step
# step:40/80 || Total Loss: 40.7322 || 1.4062s/step
# step:50/80 || Total Loss: 41.4987 || 1.7080s/step
# step:60/80 || Total Loss: 44.4016 || 1.7091s/step
# step:70/80 || Total Loss: 42.0474 || 1.3666s/step
# step:80/80 || Total Loss: 41.1756 || 1.4829s/step
# Finish Training.
# Total Loss: 40.6672 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:15/25
# Start Training.
# step:1/80 || Total Loss: 41.3964 || 1.7307s/step
# step:10/80 || Total Loss: 32.9194 || 1.2660s/step
# step:20/80 || Total Loss: 30.8790 || 1.3077s/step
# step:30/80 || Total Loss: 31.1666 || 1.4449s/step
# step:40/80 || Total Loss: 30.8719 || 1.4512s/step
# step:50/80 || Total Loss: 32.1117 || 1.5208s/step
# step:60/80 || Total Loss: 32.0780 || 1.4732s/step
# step:70/80 || Total Loss: 30.5747 || 2.0171s/step
# step:80/80 || Total Loss: 31.6406 || 1.4929s/step
# Finish Training.
# Total Loss: 31.2500 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:16/25
# Start Training.
# step:1/80 || Total Loss: 96.8694 || 1.5990s/step
# step:10/80 || Total Loss: 31.0244 || 1.2202s/step
# step:20/80 || Total Loss: 30.1628 || 1.3020s/step
# step:30/80 || Total Loss: 30.1515 || 1.5828s/step
# step:40/80 || Total Loss: 29.1983 || 1.1942s/step
# step:50/80 || Total Loss: 29.3004 || 1.6850s/step
# step:60/80 || Total Loss: 30.7450 || 1.5603s/step
# step:70/80 || Total Loss: 30.5137 || 1.3353s/step
# step:80/80 || Total Loss: 31.1143 || 1.3821s/step
# Finish Training.
# Total Loss: 30.7302 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:17/25
# Start Training.
# step:1/80 || Total Loss: 38.8130 || 1.5067s/step
# step:10/80 || Total Loss: 24.6690 || 1.4318s/step
# step:20/80 || Total Loss: 24.5420 || 1.5866s/step
# step:30/80 || Total Loss: 30.0429 || 1.4697s/step
# step:40/80 || Total Loss: 32.2353 || 1.5209s/step
# step:50/80 || Total Loss: 35.0518 || 1.6149s/step
# step:60/80 || Total Loss: 32.7558 || 1.3376s/step
# step:70/80 || Total Loss: 31.5158 || 1.4586s/step
# step:80/80 || Total Loss: 31.6702 || 1.5250s/step
# Finish Training.
# Total Loss: 31.2792 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:18/25
# Start Training.
# step:1/80 || Total Loss: 65.4964 || 1.6129s/step
# step:10/80 || Total Loss: 37.6102 || 1.5042s/step
# step:20/80 || Total Loss: 28.9397 || 1.3736s/step
# step:30/80 || Total Loss: 26.0441 || 1.2146s/step
# step:40/80 || Total Loss: 25.6876 || 1.2790s/step
# step:50/80 || Total Loss: 26.2943 || 1.5130s/step
# step:60/80 || Total Loss: 28.0330 || 1.4454s/step
# step:70/80 || Total Loss: 28.9509 || 2.4270s/step
# step:80/80 || Total Loss: 30.3101 || 1.3864s/step
# Finish Training.
# Total Loss: 29.9359 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:19/25
# Start Training.
# step:1/80 || Total Loss: 22.1966 || 1.3058s/step
# step:10/80 || Total Loss: 25.2770 || 1.4199s/step
# step:20/80 || Total Loss: 26.4443 || 1.2940s/step
# step:30/80 || Total Loss: 31.4932 || 1.3721s/step
# step:40/80 || Total Loss: 30.0042 || 1.5978s/step
# step:50/80 || Total Loss: 29.4697 || 1.6144s/step
# step:60/80 || Total Loss: 27.9464 || 1.5069s/step
# step:70/80 || Total Loss: 27.4652 || 1.1684s/step
# step:80/80 || Total Loss: 26.7580 || 2.2882s/step
# Finish Training.
# Total Loss: 26.4276 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:20/25
# Start Training.
# step:1/80 || Total Loss: 15.4468 || 1.5880s/step
# step:10/80 || Total Loss: 20.0092 || 1.3195s/step
# step:20/80 || Total Loss: 19.8370 || 1.6445s/step
# step:30/80 || Total Loss: 21.0164 || 1.4409s/step
# step:40/80 || Total Loss: 29.3957 || 1.5594s/step
# step:50/80 || Total Loss: 28.9012 || 1.3518s/step
# step:60/80 || Total Loss: 27.2521 || 1.3960s/step
# step:70/80 || Total Loss: 29.1111 || 1.8956s/step
# step:80/80 || Total Loss: 30.4617 || 1.5620s/step
# Finish Training.
# Total Loss: 30.0856 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:21/25
# Start Training.
# step:1/80 || Total Loss: 18.7375 || 1.4565s/step
# step:10/80 || Total Loss: 24.4930 || 1.5114s/step
# step:20/80 || Total Loss: 26.9397 || 1.4130s/step
# step:30/80 || Total Loss: 24.6275 || 1.6917s/step
# step:40/80 || Total Loss: 28.6921 || 1.9554s/step
# step:50/80 || Total Loss: 31.5555 || 1.4921s/step
# step:60/80 || Total Loss: 31.0642 || 1.9129s/step
# step:70/80 || Total Loss: 29.6618 || 1.6005s/step
# step:80/80 || Total Loss: 31.5484 || 1.5572s/step
# Finish Training.
# Total Loss: 31.1589 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:22/25
# Start Training.
# step:1/80 || Total Loss: 13.0610 || 1.2614s/step
# step:10/80 || Total Loss: 29.1048 || 1.5531s/step
# step:20/80 || Total Loss: 32.8935 || 2.2984s/step
# step:30/80 || Total Loss: 27.0766 || 1.3718s/step
# step:40/80 || Total Loss: 25.7145 || 1.3977s/step
# step:50/80 || Total Loss: 27.4089 || 1.6229s/step
# step:60/80 || Total Loss: 26.9059 || 1.2565s/step
# step:70/80 || Total Loss: 25.8856 || 1.6359s/step
# step:80/80 || Total Loss: 25.7547 || 1.5384s/step
# Finish Training.
# Total Loss: 25.4368 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:23/25
# Start Training.
# step:1/80 || Total Loss: 9.2295 || 1.4492s/step
# step:10/80 || Total Loss: 21.6246 || 1.3915s/step
# step:20/80 || Total Loss: 20.7045 || 1.8235s/step
# step:30/80 || Total Loss: 21.1783 || 1.8701s/step
# step:40/80 || Total Loss: 23.6824 || 1.8624s/step
# step:50/80 || Total Loss: 23.4993 || 1.5872s/step
# step:60/80 || Total Loss: 22.7731 || 1.5501s/step
# step:70/80 || Total Loss: 21.8697 || 1.6588s/step
# step:80/80 || Total Loss: 22.9877 || 1.3908s/step
# Finish Training.
# Total Loss: 22.7039 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:24/25
# Start Training.
# step:1/80 || Total Loss: 33.5284 || 1.5099s/step
# step:10/80 || Total Loss: 25.8743 || 1.4538s/step
# step:20/80 || Total Loss: 19.9969 || 1.2252s/step
# step:30/80 || Total Loss: 22.6297 || 1.1878s/step
# step:40/80 || Total Loss: 20.6835 || 1.4518s/step
# step:50/80 || Total Loss: 20.5501 || 1.3175s/step
# step:60/80 || Total Loss: 20.6833 || 1.4783s/step
# step:70/80 || Total Loss: 21.5742 || 1.4542s/step
# step:80/80 || Total Loss: 23.0580 || 1.4493s/step
# Finish Training.
# Total Loss: 22.7733 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:25/25
# Start Training.
# step:1/80 || Total Loss: 27.2013 || 1.5484s/step
# step:10/80 || Total Loss: 19.1805 || 1.2818s/step
# step:20/80 || Total Loss: 18.4927 || 1.4835s/step
# step:30/80 || Total Loss: 16.2868 || 1.2442s/step
# step:40/80 || Total Loss: 17.9178 || 1.4748s/step
# step:50/80 || Total Loss: 22.4106 || 1.7313s/step
# step:60/80 || Total Loss: 22.8638 || 1.5503s/step
# step:70/80 || Total Loss: 21.8843 || 1.5313s/step
# step:80/80 || Total Loss: 21.3555 || 1.2482s/step
# Finish Training.
# Total Loss: 21.0918 || Val Loss: 0.0000

# %%
#------------------------------------#
#   解冻backbone后训练
#------------------------------------#
lr = 1e-4
Batch_size = 2
Freeze_Epoch = 25
Unfreeze_Epoch = 40

optimizer = optim.Adam(net.parameters(), lr, weight_decay=5e-4)
if Cosine_lr:
    lr_scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=5, eta_min=1e-5)
else:
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

gen = Generator(Batch_size, train_lines, (input_shape[0], input_shape[1])).generate(mosaic = mosaic)
gen_val = Generator(Batch_size, val_lines, (input_shape[0], input_shape[1])).generate(mosaic = False)
                        
epoch_size = int(max(1, num_train//Batch_size//2.5)) if mosaic else max(1, num_train//Batch_size)
epoch_size_val = num_val//Batch_size
for param in model.backbone.parameters():
    param.requires_grad = True

best_loss = 21.091846466064453
    
for epoch in range(Freeze_Epoch, Unfreeze_Epoch):
    total_loss, val_loss = fit_one_epoch(net, yolo_losses, epoch, epoch_size, epoch_size_val, gen, gen_val, 
                                         Unfreeze_Epoch, Cuda, optimizer, lr_scheduler)
    if total_loss < best_loss:
        best_loss = total_loss
        best_model_weights = copy.deepcopy(model.state_dict())
    with open('total_loss.csv', mode='a+') as total_loss_file:
        total_loss_file.write(str(total_loss.item()) + '\n')
    #with open('val_loss.csv', mode='a+') as val_loss_file:
    #    val_loss_file.write(str(val_loss.item() + '\n')
torch.save(best_model_weights, 'model_data/yolov4_maskdetect_weights1.pth')
# Out:
# ----------Train one epoch.----------
# Epoch:26/40
# Start Training.
# step:1/160 || Total Loss: 8.7125 || 1.0300s/step
# step:10/160 || Total Loss: 10.7137 || 0.8823s/step
# step:20/160 || Total Loss: 17.1531 || 1.3484s/step
# step:30/160 || Total Loss: 14.8680 || 0.8271s/step
# step:40/160 || Total Loss: 17.0336 || 0.7746s/step
# step:50/160 || Total Loss: 16.2276 || 1.0037s/step
# step:60/160 || Total Loss: 17.0040 || 0.8280s/step
# step:70/160 || Total Loss: 18.9229 || 0.8763s/step
# step:80/160 || Total Loss: 19.3642 || 0.7406s/step
# step:90/160 || Total Loss: 18.4085 || 0.9709s/step
# step:100/160 || Total Loss: 17.4130 || 0.8443s/step
# step:110/160 || Total Loss: 16.4845 || 0.8390s/step
# step:120/160 || Total Loss: 16.2463 || 0.8858s/step
# step:130/160 || Total Loss: 15.9496 || 0.7082s/step
# step:140/160 || Total Loss: 16.2377 || 0.8815s/step
# step:150/160 || Total Loss: 16.0274 || 0.8802s/step
# step:160/160 || Total Loss: 16.2330 || 1.1385s/step
# Finish Training.
# Total Loss: 16.1321 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:27/40
# Start Training.
# step:1/160 || Total Loss: 14.8983 || 1.5396s/step
# step:10/160 || Total Loss: 15.2442 || 0.7744s/step
# step:20/160 || Total Loss: 21.2867 || 0.9677s/step
# step:30/160 || Total Loss: 21.2386 || 0.8803s/step
# step:40/160 || Total Loss: 20.5978 || 0.7865s/step
# step:50/160 || Total Loss: 21.0871 || 1.1376s/step
# step:60/160 || Total Loss: 21.1427 || 0.8071s/step
# step:70/160 || Total Loss: 19.3263 || 0.8283s/step
# step:80/160 || Total Loss: 17.7381 || 0.7629s/step
# step:90/160 || Total Loss: 17.4999 || 1.0045s/step
# step:100/160 || Total Loss: 18.6644 || 0.8677s/step
# step:110/160 || Total Loss: 18.2629 || 0.9106s/step
# step:120/160 || Total Loss: 19.6595 || 1.0721s/step
# step:130/160 || Total Loss: 19.4713 || 0.7433s/step
# step:140/160 || Total Loss: 18.8408 || 0.8195s/step
# step:150/160 || Total Loss: 18.5219 || 0.8136s/step
# step:160/160 || Total Loss: 18.6084 || 0.7388s/step
# Finish Training.
# Total Loss: 18.4928 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:28/40
# Start Training.
# step:1/160 || Total Loss: 13.5217 || 0.8389s/step
# step:10/160 || Total Loss: 13.3159 || 0.8884s/step
# step:20/160 || Total Loss: 11.5139 || 1.1097s/step
# step:30/160 || Total Loss: 12.1008 || 0.9122s/step
# step:40/160 || Total Loss: 12.8636 || 1.3438s/step
# step:50/160 || Total Loss: 15.1530 || 1.0084s/step
# step:60/160 || Total Loss: 15.7411 || 0.7518s/step
# step:70/160 || Total Loss: 15.2731 || 0.7227s/step
# step:80/160 || Total Loss: 14.7034 || 0.8172s/step
# step:90/160 || Total Loss: 14.1713 || 0.8571s/step
# step:100/160 || Total Loss: 14.3542 || 0.9641s/step
# step:110/160 || Total Loss: 14.1833 || 0.8974s/step
# step:120/160 || Total Loss: 14.4798 || 0.7863s/step
# step:130/160 || Total Loss: 13.7433 || 0.7984s/step
# step:140/160 || Total Loss: 14.9811 || 0.9932s/step
# step:150/160 || Total Loss: 15.7144 || 0.9027s/step
# step:160/160 || Total Loss: 15.2994 || 0.7403s/step
# Finish Training.
# Total Loss: 15.2044 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:29/40
# Start Training.
# step:1/160 || Total Loss: 51.9511 || 0.9733s/step
# step:10/160 || Total Loss: 18.1792 || 0.8019s/step
# step:20/160 || Total Loss: 13.2828 || 0.8093s/step
# step:30/160 || Total Loss: 12.1198 || 0.7327s/step
# step:40/160 || Total Loss: 12.5033 || 1.0058s/step
# step:50/160 || Total Loss: 13.3879 || 0.8388s/step
# step:60/160 || Total Loss: 13.4650 || 0.8850s/step
# step:70/160 || Total Loss: 14.0531 || 0.8698s/step
# step:80/160 || Total Loss: 14.5289 || 0.7764s/step
# step:90/160 || Total Loss: 13.9436 || 0.8801s/step
# step:100/160 || Total Loss: 13.6838 || 0.7750s/step
# step:110/160 || Total Loss: 14.6881 || 0.8506s/step
# step:120/160 || Total Loss: 16.0128 || 0.9973s/step
# step:130/160 || Total Loss: 16.4621 || 0.7813s/step
# step:140/160 || Total Loss: 16.2081 || 0.8921s/step
# step:150/160 || Total Loss: 16.2393 || 1.0373s/step
# step:160/160 || Total Loss: 15.8022 || 0.7599s/step
# Finish Training.
# Total Loss: 15.7041 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:30/40
# Start Training.
# step:1/160 || Total Loss: 33.0533 || 0.8664s/step
# step:10/160 || Total Loss: 19.8947 || 0.9737s/step
# step:20/160 || Total Loss: 14.2404 || 0.8803s/step
# step:30/160 || Total Loss: 15.9976 || 1.3138s/step
# step:40/160 || Total Loss: 14.7680 || 0.9074s/step
# step:50/160 || Total Loss: 14.8987 || 0.9726s/step
# step:60/160 || Total Loss: 15.4560 || 0.9712s/step
# step:70/160 || Total Loss: 14.6360 || 1.2688s/step
# step:80/160 || Total Loss: 15.0948 || 1.0615s/step
# step:90/160 || Total Loss: 18.5460 || 0.7907s/step
# step:100/160 || Total Loss: 20.0174 || 0.6880s/step
# step:110/160 || Total Loss: 18.6859 || 0.7511s/step
# step:120/160 || Total Loss: 18.5141 || 0.7380s/step
# step:130/160 || Total Loss: 17.6469 || 0.7605s/step
# step:140/160 || Total Loss: 17.5563 || 1.1103s/step
# step:150/160 || Total Loss: 17.0928 || 0.8437s/step
# step:160/160 || Total Loss: 17.1935 || 0.7585s/step
# Finish Training.
# Total Loss: 17.0867 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:31/40
# Start Training.
# step:1/160 || Total Loss: 1.8557 || 0.7168s/step
# step:10/160 || Total Loss: 9.1219 || 0.8698s/step
# step:20/160 || Total Loss: 12.4717 || 0.8457s/step
# step:30/160 || Total Loss: 10.7438 || 1.4582s/step
# step:40/160 || Total Loss: 15.3149 || 0.7632s/step
# step:50/160 || Total Loss: 15.1545 || 0.8328s/step
# step:60/160 || Total Loss: 13.8728 || 0.7771s/step
# step:70/160 || Total Loss: 15.4957 || 0.7218s/step
# step:80/160 || Total Loss: 15.4785 || 0.7443s/step
# step:90/160 || Total Loss: 14.5151 || 0.8734s/step
# step:100/160 || Total Loss: 13.6504 || 0.8332s/step
# step:110/160 || Total Loss: 13.7777 || 0.7610s/step
# step:120/160 || Total Loss: 13.3098 || 0.7702s/step
# step:130/160 || Total Loss: 12.7621 || 0.8354s/step
# step:140/160 || Total Loss: 12.1985 || 0.7531s/step
# step:150/160 || Total Loss: 12.5323 || 1.1049s/step
# step:160/160 || Total Loss: 12.9459 || 0.7280s/step
# Finish Training.
# Total Loss: 12.8655 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:32/40
# Start Training.
# step:1/160 || Total Loss: 2.6777 || 0.7708s/step
# step:10/160 || Total Loss: 29.1972 || 0.8526s/step
# step:20/160 || Total Loss: 19.4238 || 0.7880s/step
# step:30/160 || Total Loss: 23.8499 || 0.7942s/step
# step:40/160 || Total Loss: 21.6345 || 0.7927s/step
# step:50/160 || Total Loss: 22.6819 || 0.9073s/step
# step:60/160 || Total Loss: 23.1502 || 1.1161s/step
# step:70/160 || Total Loss: 21.1658 || 0.7911s/step
# step:80/160 || Total Loss: 22.0065 || 0.7488s/step
# step:90/160 || Total Loss: 20.3920 || 1.0853s/step
# step:100/160 || Total Loss: 19.3982 || 0.7569s/step
# step:110/160 || Total Loss: 19.5303 || 0.8575s/step
# step:120/160 || Total Loss: 18.6589 || 0.9216s/step
# step:130/160 || Total Loss: 17.7100 || 1.0006s/step
# step:140/160 || Total Loss: 17.7842 || 0.7777s/step
# step:150/160 || Total Loss: 17.3089 || 0.6284s/step
# step:160/160 || Total Loss: 17.7153 || 0.9246s/step
# Finish Training.
# Total Loss: 17.6053 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:33/40
# Start Training.
# step:1/160 || Total Loss: 26.9632 || 0.8609s/step
# step:10/160 || Total Loss: 22.0566 || 0.9312s/step
# step:20/160 || Total Loss: 30.6372 || 0.8061s/step
# step:30/160 || Total Loss: 23.6825 || 0.7873s/step
# step:40/160 || Total Loss: 19.9614 || 0.7387s/step
# step:50/160 || Total Loss: 19.4585 || 0.8155s/step
# step:60/160 || Total Loss: 17.3910 || 0.6923s/step
# step:70/160 || Total Loss: 15.8761 || 0.7161s/step
# step:80/160 || Total Loss: 15.9838 || 0.8213s/step
# step:90/160 || Total Loss: 16.2334 || 0.7939s/step
# step:100/160 || Total Loss: 15.6092 || 1.1515s/step
# step:110/160 || Total Loss: 15.1626 || 0.8791s/step
# step:120/160 || Total Loss: 14.6115 || 0.7755s/step
# step:130/160 || Total Loss: 14.5886 || 0.9878s/step
# step:140/160 || Total Loss: 14.7585 || 0.7334s/step
# step:150/160 || Total Loss: 15.4013 || 1.0385s/step
# step:160/160 || Total Loss: 15.3276 || 0.9441s/step
# Finish Training.
# Total Loss: 15.2324 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:34/40
# Start Training.
# step:1/160 || Total Loss: 5.4844 || 0.9544s/step
# step:10/160 || Total Loss: 8.3487 || 0.9473s/step
# step:20/160 || Total Loss: 16.7562 || 1.1867s/step
# step:30/160 || Total Loss: 18.0023 || 0.8508s/step
# step:40/160 || Total Loss: 16.5467 || 0.8674s/step
# step:50/160 || Total Loss: 17.1847 || 1.0293s/step
# step:60/160 || Total Loss: 17.4730 || 0.9549s/step
# step:70/160 || Total Loss: 16.0552 || 0.9429s/step
# step:80/160 || Total Loss: 15.3138 || 1.0442s/step
# step:90/160 || Total Loss: 14.4347 || 0.8487s/step
# step:100/160 || Total Loss: 15.4709 || 0.8402s/step
# step:110/160 || Total Loss: 15.0383 || 0.8416s/step
# step:120/160 || Total Loss: 14.6994 || 0.7579s/step
# step:130/160 || Total Loss: 14.2766 || 0.8861s/step
# step:140/160 || Total Loss: 14.0231 || 0.7257s/step
# step:150/160 || Total Loss: 13.7298 || 0.7169s/step
# step:160/160 || Total Loss: 13.3502 || 0.8724s/step
# Finish Training.
# Total Loss: 13.2673 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:35/40
# Start Training.
# step:1/160 || Total Loss: 9.1076 || 0.8031s/step
# step:10/160 || Total Loss: 18.2146 || 0.9120s/step
# step:20/160 || Total Loss: 16.3394 || 1.0326s/step
# step:30/160 || Total Loss: 13.3172 || 0.9146s/step
# step:40/160 || Total Loss: 12.8894 || 0.9023s/step
# step:50/160 || Total Loss: 12.6001 || 0.8237s/step
# step:60/160 || Total Loss: 11.9805 || 1.0154s/step
# step:70/160 || Total Loss: 11.4025 || 0.7462s/step
# step:80/160 || Total Loss: 11.8178 || 0.7431s/step
# step:90/160 || Total Loss: 11.9152 || 0.6823s/step
# step:100/160 || Total Loss: 11.9777 || 0.8242s/step
# step:110/160 || Total Loss: 12.5902 || 0.9981s/step
# step:120/160 || Total Loss: 12.0731 || 0.8305s/step
# step:130/160 || Total Loss: 11.7166 || 0.8422s/step
# step:140/160 || Total Loss: 11.8140 || 0.9957s/step
# step:150/160 || Total Loss: 12.8521 || 0.7221s/step
# step:160/160 || Total Loss: 12.6592 || 0.7943s/step
# Finish Training.
# Total Loss: 12.5805 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:36/40
# Start Training.
# step:1/160 || Total Loss: 7.2954 || 0.6922s/step
# step:10/160 || Total Loss: 13.2929 || 0.8960s/step
# step:20/160 || Total Loss: 10.8141 || 1.3121s/step
# step:30/160 || Total Loss: 9.3601 || 0.7886s/step
# step:40/160 || Total Loss: 18.7019 || 0.7763s/step
# step:50/160 || Total Loss: 16.6350 || 1.5263s/step
# step:60/160 || Total Loss: 15.0008 || 0.9453s/step
# step:70/160 || Total Loss: 14.2347 || 0.7256s/step
# step:80/160 || Total Loss: 16.5101 || 0.8009s/step
# step:90/160 || Total Loss: 16.7051 || 1.0169s/step
# step:100/160 || Total Loss: 16.5758 || 0.7497s/step
# step:110/160 || Total Loss: 17.1335 || 0.8397s/step
# step:120/160 || Total Loss: 16.3832 || 0.8181s/step
# step:130/160 || Total Loss: 15.7089 || 0.8854s/step
# step:140/160 || Total Loss: 16.1059 || 0.9085s/step
# step:150/160 || Total Loss: 15.6476 || 0.9023s/step
# step:160/160 || Total Loss: 15.3461 || 1.0223s/step
# Finish Training.
# Total Loss: 15.2508 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:37/40
# Start Training.
# step:1/160 || Total Loss: 11.1701 || 0.7779s/step
# step:10/160 || Total Loss: 12.6268 || 0.8747s/step
# step:20/160 || Total Loss: 10.1028 || 0.7966s/step
# step:30/160 || Total Loss: 10.6560 || 0.8081s/step
# step:40/160 || Total Loss: 9.8752 || 0.9222s/step
# step:50/160 || Total Loss: 11.7444 || 0.7050s/step
# step:60/160 || Total Loss: 11.2047 || 0.7760s/step
# step:70/160 || Total Loss: 12.5525 || 0.7606s/step
# step:80/160 || Total Loss: 12.2313 || 1.1434s/step
# step:90/160 || Total Loss: 11.6045 || 0.8659s/step
# step:100/160 || Total Loss: 11.3385 || 0.7302s/step
# step:110/160 || Total Loss: 11.3916 || 0.7482s/step
# step:120/160 || Total Loss: 11.4768 || 0.7916s/step
# step:130/160 || Total Loss: 11.4368 || 0.7158s/step
# step:140/160 || Total Loss: 11.8022 || 1.0039s/step
# step:150/160 || Total Loss: 12.3007 || 0.8895s/step
# step:160/160 || Total Loss: 12.4892 || 0.7569s/step
# Finish Training.
# Total Loss: 12.4116 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:38/40
# Start Training.
# step:1/160 || Total Loss: 21.1149 || 0.8699s/step
# step:10/160 || Total Loss: 12.1220 || 1.0616s/step
# step:20/160 || Total Loss: 10.1696 || 0.7294s/step
# step:30/160 || Total Loss: 10.2615 || 0.8314s/step
# step:40/160 || Total Loss: 10.0543 || 0.8515s/step
# step:50/160 || Total Loss: 11.0652 || 0.8978s/step
# step:60/160 || Total Loss: 10.2930 || 0.8522s/step
# step:70/160 || Total Loss: 10.0847 || 0.8481s/step
# step:80/160 || Total Loss: 9.9267 || 0.8485s/step
# step:90/160 || Total Loss: 10.8986 || 1.0390s/step
# step:100/160 || Total Loss: 11.1008 || 0.9333s/step
# step:110/160 || Total Loss: 10.5888 || 0.8395s/step
# step:120/160 || Total Loss: 12.6542 || 0.7561s/step
# step:130/160 || Total Loss: 12.8414 || 0.7388s/step
# step:140/160 || Total Loss: 13.1929 || 0.9753s/step
# step:150/160 || Total Loss: 14.1053 || 0.8343s/step
# step:160/160 || Total Loss: 13.7547 || 0.8138s/step
# Finish Training.
# Total Loss: 13.6692 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:39/40
# Start Training.
# step:1/160 || Total Loss: 11.2400 || 0.9152s/step
# step:10/160 || Total Loss: 7.1786 || 0.8167s/step
# step:20/160 || Total Loss: 7.6742 || 0.8726s/step
# step:30/160 || Total Loss: 7.9267 || 0.8213s/step
# step:40/160 || Total Loss: 8.8181 || 0.9144s/step
# step:50/160 || Total Loss: 10.0179 || 0.9005s/step
# step:60/160 || Total Loss: 11.2593 || 0.9455s/step
# step:70/160 || Total Loss: 13.0581 || 0.7195s/step
# step:80/160 || Total Loss: 13.0362 || 0.8337s/step
# step:90/160 || Total Loss: 12.5865 || 0.7026s/step
# step:100/160 || Total Loss: 12.1671 || 0.7939s/step
# step:110/160 || Total Loss: 11.9764 || 0.7236s/step
# step:120/160 || Total Loss: 11.5709 || 0.8174s/step
# step:130/160 || Total Loss: 11.1846 || 0.7967s/step
# step:140/160 || Total Loss: 10.8175 || 0.8411s/step
# step:150/160 || Total Loss: 10.5839 || 0.7433s/step
# step:160/160 || Total Loss: 11.1100 || 0.9754s/step
# Finish Training.
# Total Loss: 11.0410 || Val Loss: 0.0000
#
# ----------Train one epoch.----------
# Epoch:40/40
# Start Training.
# step:1/160 || Total Loss: 8.4951 || 0.7594s/step
# step:10/160 || Total Loss: 8.4592 || 1.1818s/step
# step:20/160 || Total Loss: 13.0322 || 0.9246s/step
# step:30/160 || Total Loss: 12.1513 || 0.9379s/step
# step:40/160 || Total Loss: 12.2059 || 0.8140s/step
# step:50/160 || Total Loss: 11.8152 || 0.7438s/step
# step:60/160 || Total Loss: 16.2079 || 0.9301s/step
# step:70/160 || Total Loss: 15.7564 || 0.9606s/step
# step:80/160 || Total Loss: 15.5048 || 0.8376s/step
# step:90/160 || Total Loss: 15.0275 || 0.9470s/step
# step:100/160 || Total Loss: 14.5422 || 1.0852s/step
# step:110/160 || Total Loss: 13.8861 || 0.8233s/step
# step:120/160 || Total Loss: 13.9431 || 0.7619s/step
# step:130/160 || Total Loss: 13.7396 || 1.1554s/step
# step:140/160 || Total Loss: 15.5701 || 0.6000s/step
# step:150/160 || Total Loss: 15.0613 || 0.8012s/step
# step:160/160 || Total Loss: 14.8718 || 0.9105s/step
# Finish Training.
# Total Loss: 14.7794 || Val Loss: 0.0000
